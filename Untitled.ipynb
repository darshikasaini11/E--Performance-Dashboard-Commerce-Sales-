# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/ecommerce_cleaned.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../data/processed/ecommerce_cleaned.csv")
#       3 df.head()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\E--Performance-Dashboard-Commerce-Sales--main\\E--Performance-Dashboard-Commerce-Sales--main'

# %%
import os

print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data"))
# Out:
# ['raw']

# %%
print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\processed"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\processed"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\HP\\Desktop\\E--Performance-Dashboard-Commerce-Sales--main\\E--Performance-Dashboard-Commerce-Sales--main\\data\\processed'

# %%
data/processed/ecommerce_cleaned.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data/processed/ecommerce_cleaned.csv
#
# NameError: name 'data' is not defined

# %%
data/raw/ecommerce_cleaned.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data/raw/ecommerce_cleaned.csv
#
# NameError: name 'data' is not defined

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\processed\ecommerce_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\processed\ecommerce_cleaned.csv")
#
# ...

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\raw\your_file.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\raw\your_file.csv")
#
# ...

# %%
import os

print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data"))
# Out:
# ['raw']

# %%
print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\raw"))
# Out:
# ['.gitkeep', 'data']

# %%
print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\processed"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data\processed"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\HP\\Desktop\\E--Performance-Dashboard-Commerce-Sales--main\\E--Performance-Dashboard-Commerce-Sales--main\\data\\processed'

# %%
import os

print(os.listdir(r"C:\Users\HP\Desktop\E--Performance-Dashboard-Commerce-Sales--main\E--Performance-Dashboard-Commerce-Sales--main\data"))
# Out:
# ['raw']

# %%
python src/data_cleaning.py
# Out:
#   Cell In[14], line 1
#     python src/data_cleaning.py
#            ^
# SyntaxError: invalid syntax

# %%
data/raw/orders.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data/raw/orders.csv
#
# NameError: name 'data' is not defined

# %%
data/raw/
# Out:
#   Cell In[16], line 1
#     data/raw/
#              ^
# SyntaxError: invalid syntax

# %%
import os

print(os.listdir("data/raw"))
# Out:
# ['.gitkeep', 'data']

# %%
import os

print(os.listdir("data/raw/data"))
# Out:
# ['processed']

# %%
orders = pd.read_csv("data/raw/data/orders.csv")
order_items = pd.read_csv("data/raw/data/order_items.csv")
products = pd.read_csv("data/raw/data/products.csv")
customers = pd.read_csv("data/raw/data/customers.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 orders = pd.read_csv("data/raw/data/orders.csv")
#       2 order_items = pd.read_csv("data/raw/data/order_items.csv")
#       3 products = pd.read_csv("data/raw/data/products.csv")
#
# ...

# %%
os.listdir("data/raw/data")
# Out:
# ['processed']

# %%
python src/data_cleaning.py
# Out:
#   Cell In[21], line 1
#     python src/data_cleaning.py
#            ^
# SyntaxError: invalid syntax
